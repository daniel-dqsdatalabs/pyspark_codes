# %%
from pyspark.sql import SparkSession
spark = SparkSession\
    .builder\
    .appName("XML Parse")\
    .config("spark.sql.shuffle.partitions", "10")\
    .config("spark.metrics.conf.*.sink.console.class", "org.apache.spark.metrics.sink.ConsoleSink")\
    .getOrCreate()

# %%
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

# %%
lines = sqlContext.read\
    .format("com.databricks.spark.xml")\
    .option("rowTag", "XML_FILE")\
    .option("inferSchema", "false")\
    .load('hdfs://localhost:8020/user/danielqueiroz/datalake/raw/example_*.xml')

# %%
lines.printSchema()
# Out:
# root
#  |-- LIMIT: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- AVAILABLE: string (nullable = true)
#  |    |    |-- AVAILABLE_AMOUNT: string (nullable = true)
#  |    |    |-- AVAILABLE_AMOUNT_USD: string (nullable = true)
#  |    |    |-- BLOCKED: string (nullable = true)
#  |    |    |-- CAP_LIST: struct (nullable = true)
#  |    |    |    |-- CAP: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- AVAILABLE: string (nullable = true)
#  |    |    |    |    |    |-- AVAILABLE_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- AVAILABLE_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |-- BLOCKED: string (nullable = true)
#  |    |    |    |    |    |-- CATEGORY: string (nullable = true)
#  |    |    |    |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |    |    |    |-- END_DATE: string (nullable = true)
#  |    |    |    |    |    |-- EXTENSION_DATE: string (nullable = true)
#  |    |    |    |    |    |-- FACILITY_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- FACILITY: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- ALLOCATING_ENTITY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- AVAILABLE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- AVAILABLE_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- AVAILABLE_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- BLOCKED: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- BOOKING_ENTITY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- BORROWER_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- INSTITUTIONAL_CODE: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- BUSINESS_LINE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CATEGORY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- COLLATERAL_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- COLLATERAL: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- COLLATERAL_TYPE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- EVALUATION: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- FIXED_VALUE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- FIXED_VALUE_FLAG: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- GROUP_NUMBER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- LEA_COLLATERAL_ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- LEVEL1: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- LEVEL2: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- MIN_PERCENT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- REFERENCE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- COMMITED: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CURRENCY_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- CURRENCY: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- DECREASING: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- END_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- EXPOSURE_TYPE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- EXTENSION_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- FACILITY_CODE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- FACILITY_PURPOSE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- FIRST_MAKER_DT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- FIRST_MAKER_ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- GLOBAL_FACILITY_ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- LAST_APPROVAL_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- LIMIT_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- LIMIT_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- LOCAL_FACILITY_ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- MAX_MATURITY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- OBSERVATION_TEXT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- ORIGINAL_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- ORIGINATING_ENTITY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- PARENT_ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- PORTFOLIO_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- PORTFOLIO_CODE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- PRE_DISBURSEMENT_TEXT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- PRODUCT_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- PRODUCT: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- RENEWABLE_COSTING: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- RESERVATION_LIST: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- REVOLVING: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- SENIORITY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- START_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- STATUS: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- TENOR: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- TYPE_OF_FACILITY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- TYPE_OF_FINANCE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- UTILIZATION_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- UTILIZATION_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- UTILIZATION_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- UTILIZATION: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- AMOUNT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- BUSINESS_UNIT_CODE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- CUSTOMER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- END_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- PRODUCT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- SOURCE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- START_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- _TRADE_REF_ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- WARNING_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- WARNING: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- JUSTIFICATION: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- REASON: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- RESPONSIBLE_USER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- WARNING_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- _ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- _ID: string (nullable = true)
#  |    |    |    |    |    |-- LAST_APPROVAL_DATE: string (nullable = true)
#  |    |    |    |    |    |-- LIMIT_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- LIMIT_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |-- LOCAL_FACILITY_ID: string (nullable = true)
#  |    |    |    |    |    |-- OBSERVATION_TEXT: string (nullable = true)
#  |    |    |    |    |    |-- ORIGINAL_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- PARENT_ID: string (nullable = true)
#  |    |    |    |    |    |-- PRE_DISBURSEMENT_TEXT: string (nullable = true)
#  |    |    |    |    |    |-- REVOLVING: string (nullable = true)
#  |    |    |    |    |    |-- START_DATE: string (nullable = true)
#  |    |    |    |    |    |-- STATUS: string (nullable = true)
#  |    |    |    |    |    |-- UTILIZATION_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- UTILIZATION_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |-- WARNING_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- WARNING: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- JUSTIFICATION: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- REASON: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- RESPONSIBLE_USER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- WARNING_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- _ID: string (nullable = true)
#  |    |    |    |    |    |-- _ID: string (nullable = true)
#  |    |    |-- CATEGORY: string (nullable = true)
#  |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |-- END_DATE: string (nullable = true)
#  |    |    |-- EXTENSION_DATE: string (nullable = true)
#  |    |    |-- FACILITY_LIST: struct (nullable = true)
#  |    |    |    |-- FACILITY: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ALLOCATING_ENTITY: string (nullable = true)
#  |    |    |    |    |    |-- AVAILABLE: string (nullable = true)
#  |    |    |    |    |    |-- AVAILABLE_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- AVAILABLE_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |-- BLOCKED: string (nullable = true)
#  |    |    |    |    |    |-- BOOKING_ENTITY: string (nullable = true)
#  |    |    |    |    |    |-- BORROWER_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- INSTITUTIONAL_CODE: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- BUSINESS_LINE: string (nullable = true)
#  |    |    |    |    |    |-- CATEGORY: string (nullable = true)
#  |    |    |    |    |    |-- COLLATERAL_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- COLLATERAL: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- COLLATERAL_TYPE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- EVALUATION: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- FIXED_VALUE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- FIXED_VALUE_FLAG: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- GROUP_NUMBER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- LEA_COLLATERAL_ID: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- LEVEL1: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- LEVEL2: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- MIN_PERCENT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- REFERENCE: string (nullable = true)
#  |    |    |    |    |    |-- COMMITED: string (nullable = true)
#  |    |    |    |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |    |    |    |-- CURRENCY_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- CURRENCY: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- DECREASING: string (nullable = true)
#  |    |    |    |    |    |-- END_DATE: string (nullable = true)
#  |    |    |    |    |    |-- EXPOSURE_TYPE: string (nullable = true)
#  |    |    |    |    |    |-- EXTENSION_DATE: string (nullable = true)
#  |    |    |    |    |    |-- FACILITY_CODE: string (nullable = true)
#  |    |    |    |    |    |-- FACILITY_PURPOSE: string (nullable = true)
#  |    |    |    |    |    |-- FIRST_MAKER_DT: string (nullable = true)
#  |    |    |    |    |    |-- FIRST_MAKER_ID: string (nullable = true)
#  |    |    |    |    |    |-- GLOBAL_FACILITY_ID: string (nullable = true)
#  |    |    |    |    |    |-- LAST_APPROVAL_DATE: string (nullable = true)
#  |    |    |    |    |    |-- LIMIT_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- LIMIT_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |-- LOCAL_FACILITY_ID: string (nullable = true)
#  |    |    |    |    |    |-- MAX_MATURITY: string (nullable = true)
#  |    |    |    |    |    |-- OBSERVATION_TEXT: string (nullable = true)
#  |    |    |    |    |    |-- ORIGINAL_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- ORIGINATING_ENTITY: string (nullable = true)
#  |    |    |    |    |    |-- PARENT_ID: string (nullable = true)
#  |    |    |    |    |    |-- PORTFOLIO_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- PORTFOLIO_CODE: string (nullable = true)
#  |    |    |    |    |    |-- PRE_DISBURSEMENT_TEXT: string (nullable = true)
#  |    |    |    |    |    |-- PRODUCT_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- PRODUCT: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- RENEWABLE_COSTING: string (nullable = true)
#  |    |    |    |    |    |-- RESERVATION_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- RESERVATION: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- AMOUNT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- BUSINESS_UNIT_CODE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CUSTOMER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- PRODUCT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- START_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- _RESERVE_ID: string (nullable = true)
#  |    |    |    |    |    |-- REVOLVING: string (nullable = true)
#  |    |    |    |    |    |-- SENIORITY: string (nullable = true)
#  |    |    |    |    |    |-- START_DATE: string (nullable = true)
#  |    |    |    |    |    |-- STATUS: string (nullable = true)
#  |    |    |    |    |    |-- TENOR: string (nullable = true)
#  |    |    |    |    |    |-- TYPE_OF_FACILITY: string (nullable = true)
#  |    |    |    |    |    |-- TYPE_OF_FINANCE: string (nullable = true)
#  |    |    |    |    |    |-- UTILIZATION_AMOUNT: string (nullable = true)
#  |    |    |    |    |    |-- UTILIZATION_AMOUNT_USD: string (nullable = true)
#  |    |    |    |    |    |-- UTILIZATION_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- UTILIZATION: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- AMOUNT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- BUSINESS_UNIT_CODE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CURRENCY: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CUSTOMER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- END_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- PRODUCT: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- SOURCE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- START_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- _TRADE_REF_ID: string (nullable = true)
#  |    |    |    |    |    |-- WARNING_LIST: struct (nullable = true)
#  |    |    |    |    |    |    |-- WARNING: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- JUSTIFICATION: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- REASON: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- RESPONSIBLE_USER: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- WARNING_DATE: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- _ID: string (nullable = true)
#  |    |    |    |    |    |-- _ID: string (nullable = true)
#  |    |    |-- LAST_APPROVAL_DATE: string (nullable = true)
#  |    |    |-- LIMIT_AMOUNT: string (nullable = true)
#  |    |    |-- LIMIT_AMOUNT_USD: string (nullable = true)
#  |    |    |-- LOCAL_FACILITY_ID: string (nullable = true)
#  |    |    |-- OBSERVATION_TEXT: string (nullable = true)
#  |    |    |-- ORIGINAL_AMOUNT: string (nullable = true)
#  |    |    |-- PRE_DISBURSEMENT_TEXT: string (nullable = true)
#  |    |    |-- REVOLVING: string (nullable = true)
#  |    |    |-- START_DATE: string (nullable = true)
#  |    |    |-- STATUS: string (nullable = true)
#  |    |    |-- UTILIZATION_AMOUNT: string (nullable = true)
#  |    |    |-- UTILIZATION_AMOUNT_USD: string (nullable = true)
#  |    |    |-- WARNING_LIST: struct (nullable = true)
#  |    |    |    |-- WARNING: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- JUSTIFICATION: string (nullable = true)
#  |    |    |    |    |    |-- REASON: string (nullable = true)
#  |    |    |    |    |    |-- RESPONSIBLE_USER: string (nullable = true)
#  |    |    |    |    |    |-- WARNING_DATE: string (nullable = true)
#  |    |    |    |    |    |-- _ID: string (nullable = true)
#  |    |    |-- _ID: string (nullable = true)
#  |-- _BASE_DATE: string (nullable = true)

# %%
# realiza as tranformações necessárias para realizar o parse do xml

from pyspark.sql.types import *
from pyspark.sql import functions as F

# carrega a estrutura inicial do xml
lines_transf_001 = lines\
    .select(
        F.col("_BASE_DATE").alias("base_date"), 
        F.explode("LIMIT").alias("limit")
    )

result = lines_transf_001\
    .selectExpr(
        "base_date", 
        "limit._ID as limit_id", 
        "explode(limit.FACILITY_LIST.FACILITY) as facility")\
    .selectExpr(
        "base_date", 
        "limit_id", 
        "facility._ID as facility_id", 
        "facility.PARENT_ID as facility_parent_id", 
        "facility.LOCAL_FACILITY_ID as facility_local_id",
        "facility.GLOBAL_FACILITY_ID as facility_global_id",
        "explode(facility.UTILIZATION_LIST.UTILIZATION) as utilization")\
    .selectExpr(
        "base_date", 
        "limit_id", 
        "facility_id", 
        "facility_parent_id",
        "facility_local_id", 
        "facility_global_id", 
        "utilization._TRADE_REF_ID AS trade_ref_id")\
    .select( 
        "base_date",
        "limit_id",
        "facility_id", 
        "facility_parent_id",
        "facility_local_id", 
        "facility_global_id",
        "trade_ref_id"
    )

# %%
result.explain()
# Out:
# == Physical Plan ==
# *(2) Project [base_date#740, limit_id#745, _gen_alias_787#787 AS facility_id#753, _gen_alias_788#788 AS facility_parent_id#754, _gen_alias_789#789 AS facility_local_id#755, _gen_alias_790#790 AS facility_global_id#756, utilization#763._TRADE_REF_ID AS trade_ref_id#771]
# +- Generate explode(_gen_alias_791#791), [base_date#740, limit_id#745, _gen_alias_787#787, _gen_alias_788#788, _gen_alias_789#789, _gen_alias_790#790], false, [utilization#763]
#    +- *(1) Project [base_date#740, _gen_alias_792#792 AS limit_id#745, facility#749._ID AS _gen_alias_787#787, facility#749.PARENT_ID AS _gen_alias_788#788, facility#749.LOCAL_FACILITY_ID AS _gen_alias_789#789, facility#749.GLOBAL_FACILITY_ID AS _gen_alias_790#790, facility#749.UTILIZATION_LIST.UTILIZATION AS _gen_alias_791#791]
#       +- Generate explode(_gen_alias_793#793), [base_date#740, _gen_alias_792#792], false, [facility#749]
#          +- Project [_BASE_DATE#737 AS base_date#740, limit#742._ID AS _gen_alias_792#792, limit#742.FACILITY_LIST.FACILITY AS _gen_alias_793#793]
#             +- Generate explode(LIMIT#736), [_BASE_DATE#737], false, [limit#742]
#                +- Scan XmlRelation(com.databricks.spark.xml.DefaultSource$$Lambda$833/219090960@233e902,Some(hdfs://localhost:8020/user/danielqueiroz/datalake/raw/credit_position_202009031634.xml),Map(inferschema -> false, rowtag -> CREDIT_POSITION, path -> hdfs://localhost:8020/user/danielqueiroz/datalake/raw/credit_position_202009031634.xml),null) [LIMIT#736,_BASE_DATE#737] PushedFilters: [], ReadSchema: struct<LIMIT:array<struct<AVAILABLE:string,AVAILABLE_AMOUNT:string,AVAILABLE_AMOUNT_USD:string,BL...

# %%
result.printSchema()
# Out:
# root
#  |-- base_date: string (nullable = true)
#  |-- limit_id: string (nullable = true)
#  |-- facility_id: string (nullable = true)
#  |-- facility_parent_id: string (nullable = true)
#  |-- facility_local_id: string (nullable = true)
#  |-- facility_global_id: string (nullable = true)
#  |-- trade_ref_id: string (nullable = true)
